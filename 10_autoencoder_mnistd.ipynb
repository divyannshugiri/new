# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model

# %%
# Load and preprocess the MNIST dataset
file_path = 'mnist_784_csv.csv'  # replace with your actual file path
mnist_data = pd.read_csv(file_path)

# %%
mnist_features = mnist_data.drop(columns=mnist_data.columns[0], axis=1)
mnist_images = mnist_features.values / 255.0

# %%
mnist_images = mnist_images.reshape(-1, 28, 28, 1)

# %%
x_train, x_test = train_test_split(mnist_images, test_size=0.2, random_state=42)

# %%
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# %%
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
input_img = Input(shape=(28, 28, 1))

# %%
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# %%
# Decoder
x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# %%
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 57s 242ms/step - loss: 0.3643 - val_loss: 0.1460
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 52s 238ms/step - loss: 0.1387 - val_loss: 0.1271
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 247ms/step - loss: 0.1252 - val_loss: 0.1199
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 52s 237ms/step - loss: 0.1194 - val_loss: 0.1159
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 52s 239ms/step - loss: 0.1155 - val_loss: 0.1134
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 52s 236ms/step - loss: 0.1135 - val_loss: 0.1116
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 239ms/step - loss: 0.1121 - val_loss: 0.1104
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 82s 235ms/step - loss: 0.1102 - val_loss: 0.1094
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 52s 236ms/step - loss: 0.1089 - val_loss: 0.1079
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 53s 240ms/step - loss: 0.1082 - val_loss: 0.1070
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - loss: 0.1070 - val_loss: 0.1067
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 173s 711ms/step - loss: 0.1063 - val_loss: 0.1054
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.1057 - val_loss: 0.1050
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 28s 128ms/step - loss: 0.1051 - val_loss: 0.1045
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 28s 129ms/step - loss: 0.1044 - val_loss: 0.1040
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - loss: 0.1041 - val_loss: 0.1039
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.1035 - val_loss: 0.1031
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.1031 - val_loss: 0.1035
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.1029 - val_loss: 0.1026
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 42s 136ms/step - loss: 0.1027 - val_loss: 0.1024
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 133ms/step - loss: 0.1022 - val_loss: 0.1020
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 836s 4s/step - loss: 0.1023 - val_loss: 0.1017
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 141ms/step - loss: 0.1020 - val_loss: 0.1015
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 136ms/step - loss: 0.1019 - val_loss: 0.1016
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 133ms/step - loss: 0.1016 - val_loss: 0.1012
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - loss: 0.1013 - val_loss: 0.1010
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - loss: 0.1011 - val_loss: 0.1007
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 138ms/step - loss: 0.1008 - val_loss: 0.1005
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 33s 149ms/step - loss: 0.1008 - val_loss: 0.1006
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - loss: 0.1006 - val_loss: 0.1005
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 134ms/step - loss: 0.1004 - val_loss: 0.1002
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - loss: 0.1003 - val_loss: 0.1000
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.1001 - val_loss: 0.1002
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 28s 129ms/step - loss: 0.1003 - val_loss: 0.0998
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.0999 - val_loss: 0.0997
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 44s 142ms/step - loss: 0.0998 - val_loss: 0.1001
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 146ms/step - loss: 0.0999 - val_loss: 0.0998
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 142ms/step - loss: 0.0996 - val_loss: 0.0996
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 143ms/step - loss: 0.0996 - val_loss: 0.0993
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 33s 153ms/step - loss: 0.0994 - val_loss: 0.0993
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 40s 146ms/step - loss: 0.0993 - val_loss: 0.0991
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 38s 131ms/step - loss: 0.0993 - val_loss: 0.0991
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - loss: 0.0991 - val_loss: 0.0990
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.0990 - val_loss: 0.0990
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.0991 - val_loss: 0.0989
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 131ms/step - loss: 0.0990 - val_loss: 0.0989
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 28s 130ms/step - loss: 0.0990 - val_loss: 0.0988
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 132ms/step - loss: 0.0990 - val_loss: 0.0987
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - loss: 0.0989 - val_loss: 0.0986
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 134ms/step - loss: 0.0985 - val_loss: 0.0985

# %%
denoised_imgs = autoencoder.predict(x_test_noisy)
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step

# %%
n = 10  # number of images to display
plt.figure(figsize=(18, 6))
for i in range(n):
    # Display original images (First row)
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
    
    # Display noisy images (Second row)
    ax = plt.subplot(3, n, i + n + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
    
    # Display denoised images (Third row)
    ax = plt.subplot(3, n, i + 2 * n + 1)
    plt.imshow(denoised_imgs[i].reshape(28, 28), cmap='gray')
    plt.axis('off')

plt.show()
